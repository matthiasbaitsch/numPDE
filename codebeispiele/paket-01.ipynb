# %% [markdown]
# # Codebeispiele zu Paket 1 - Mathematik Bohrpfahl

# %% [markdown]
# Wir verwenden das Paket [MMJMesh](https://matthiasbaitsch.github.io/mmjmesh/guide).

# %%
using CairoMakie
using MMJMesh.Plots
using MMJMesh.Mathematics

# %% [markdown]
# ## Funktionen in MMJMesh.Mathematics

# %% [markdown]
# Ableitungen

# %% [markdown]
# Integrale

# %% [markdown]
# ## Differentialgleichungen

# %% [markdown]
# Gesucht ist eine beliebige Lösung der DGL $u''(x) + u(x) = 0$ for $0 < x < 4\pi$.

# %% [markdown]
# ## Aufgabenblatt 1
#
# ### Aufgabe 2

# %% [markdown]
# l = 10
# EA = 1
